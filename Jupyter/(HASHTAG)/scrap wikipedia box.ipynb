# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
import time

driver = webdriver.Chrome()

ti = time.time()

links = [
    'https://en.wikipedia.org/wiki/NBA_Jam_(1993_video_game)'
]

print ('------------------------------------------')

for a in links:
    try:
        #driver.get("https://pt.aliexpress.com/item/4000335784936.html")
        driver.get(a)
        #time.sleep(3)

        #imagem   /html/body/div[6]/div/div[2]/div/div[1]/div/div/div[1]/div[2]
        titulo=driver.find_element(By.XPATH, '/html/body/div[3]/h1').text
        tabela_box=driver.find_element(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table/tbody').text
        #plataformas=driver.find_element(By.XPATH, "/html/body/div[3]/div[3]/div[5]/div[1]/table/tbody[contains(text(),'Plataform')]").text
        
        #plataformas=driver.find_element_by_xpath("//[contains(text(),'Plataform')]")
        
        print(a)
        print('Título       :', titulo)
        print('Tabela_Box   :', tabela_box)
        print ('------------------------------------------')
        #print(plataformas)
        #time.sleep(2)
    except:
        print(a)
        print('Erro.')
        print ('------------------------------------------')

'''
for item in tabela_box:
    #if 'Platform' in item:
    print('Item: ', item)
'''        

tf = time.time()

tt = tf - ti

print('Tempo de execução: {} segundos'.format(tt))

driver.close()
# Out:
# ------------------------------------------
# https://en.wikipedia.org/wiki/NBA_Jam_(1993_video_game)
# Título       : NBA Jam (1993 video game)
# Tabela_Box   : NBA Jam
# Arcade promotional flyer
# Developer(s) Midway
# Iguana Entertainment (consoles, GG)
# Beam Software (Game Boy)
# Torus Games (Tournament Edition GB)
# Publisher(s) Midway
# Acclaim Entertainment[a] (consoles)
# Designer(s) Mark Turmell, Shawn Liptak, Jamie Rivett, Sal Divita, John Carlton, Tony Goskie
# Composer(s) Jon Hey (Arcade)
# Rick Fox (Genesis/SNES)
# Series NBA Jam
# Platform(s) Arcade, Super NES, Sega Genesis, Game Gear, Master System, Game Boy, Sega CD, 32X, Atari Jaguar, Sega Saturn, PlayStation
# Release NBA Jam
# Arcade
# NA: April 1993[1]
# Game Gear & Sega Genesis & SNES
# NA: March 4, 1994
# EU: 1994
# JP: April 29, 1994
# Game Boy
# NA: November 1994
# EU: November 24, 1994
# JP: 1994
# Sega CD
# NA: 1994
# EU: 1994
# JP: December 20, 1994
# Tournament Edition
# Arcade
# NA: February 23, 1995
# ...
