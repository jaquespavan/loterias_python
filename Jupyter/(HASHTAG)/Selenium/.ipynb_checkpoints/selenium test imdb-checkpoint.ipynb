# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

#from selenium.webdriver.chrome.service import Service
#from webdriver_manager.chrome import ChromeDriverManager

#servico = Service(ChromeDriverManager().install())
#driver = webdriver.Chrome(service=servico)

driver = webdriver.Chrome()

# %%
#from selenium.webdriver.common.by import By

#driver.get(r'D:\FILMES\[TERROR]\Jogos Mortais – 2004 – Versão do Diretor – Dublagem Clássica – Trial Áudio – Bluray 1080p – Adoro Filmes de Terror.mhtml')

list = [
    'https://www.imdb.com/title/tt0088763/',
    'https://www.imdb.com/title/tt0096874/',
    'https://www.imdb.com/title/tt0099088/'
]

xpath_titulo = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1'
xpath_titulo_original = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/div'
xpath_ano = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/span'
xpath_duracao = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]'
xpath_direcao = '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/ul/li[1]/div/ul/li/a'

for a in list:
    driver.get(a)
    titulo = driver.find_element(By.XPATH, xpath_titulo).text
    titulo_original = driver.find_element(By.XPATH, xpath_titulo_original).text
    ano = driver.find_element(By.XPATH, xpath_ano).text
    duracao = driver.find_element(By.XPATH, xpath_duracao).text
    direcao = driver.find_element(By.XPATH, xpath_direcao).text
    #print(titulo)
    #print(titulo_original)
    #print(ano)
    #print(duracao)
    
    print('{} ({}). {}.'.format(titulo, titulo_original, ano))
    print('Direção: {}'.format(direcao))
    print(duracao)
    print('')
# Out:
# De Volta para o Futuro (Título original: Back to the Future). .
# Direção: Robert Zemeckis
# 1 h 56 min
#
# De Volta para o Futuro II (Título original: Back to the Future Part II). .
# Direção: Robert Zemeckis
# 1 h 48 min
#
# De Volta para o Futuro III (Título original: Back to the Future Part III). .
# Direção: Robert Zemeckis
# 1 h 58 min

# %%
from selenium.webdriver.common.by import By
import random

'''
list = [
    'https://www.imdb.com/title/tt0088763/',
    'https://www.imdb.com/title/tt0096874/',
    'https://www.imdb.com/title/tt0099088/'
]
'''

inicio = random.randrange(0, 1999999)
fim = 1999999
step = random.randrange(90000, 300000)

r = range(inicio, fim, step)

print('Início: {}'. format(inicio))
print('Fim   : {}'. format(fim))
print('Step  : {}\n'.format(step))

for n in r:
    
    id_imdb = str(n).zfill(7)
    
    link = 'https://www.imdb.com/title/tt{}/'.format(id_imdb)

    xpath_titulo = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1'
    xpath_titulo_original = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/div'
    xpath_ano = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/a'
    xpath_duracao = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]'
    #xpath_direcao = '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/ul/li[1]/div/ul/li/a'
    #xpath_direcao = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div/ul/li/a/text()'
    xpath_direcao = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[3]/ul/li[1]/div/ul/li/a/'
    xpath_pais = '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[8]/div[2]/ul/li[2]/div/ul/li/a'
    
    class_titulo = 'sc-b73cd867-0'
    class_titulo_original = 'sc-dae4a1bc-0'
    class_ano = 'sc-8c396aa2-1'
    class_duracao = 'ipc-inline-list__item'
    class_direcao = 'ipc-metadata-list-item__list-content-item'
    class_pais = 'ipc-metadata-list-item__list-content-item'
    
    titulo = ''
    titulo_original = ''
    ano = ''
    duracao = ''
    direcao = ''
    pais = ''

    driver.get(link)

    '''
    try:
        titulo = driver.find_element(By.XPATH, xpath_titulo).text
    except:
        titulo = ''
    '''    
    try:
        titulo = driver.find_element(By.CLASS_NAME, class_titulo).text
    except:
        titulo = ''
    
    '''
    try:
        titulo_original = driver.find_element(By.XPATH, xpath_titulo_original).text
    except:
        titulo_original = titulo
    '''        
    
    try:
        titulo_original = driver.find_element(By.CLASS_NAME, class_titulo_original).text
    except:
        titulo_original = titulo
    
    '''
    try:
        ano = driver.find_element(By.XPATH, xpath_ano).text
    except:
        ano = '0000'
    '''    
    
    try:
        ano = driver.find_element(By.CLASS_NAME, class_ano).text
    except:
        ano = '0000'
    
    '''
    try:
        duracao = driver.find_element(By.XPATH, xpath_duracao).text
    except:
        duracao = '0'
    '''

    try:
        duracao = driver.find_element(By.CLASS_NAME, class_duracao).text
    except:
        duracao = '0'
    
    '''
    try:
        direcao = driver.find_element(By.XPATH, xpath_direcao)#.text
    except:
        direção = 'ONON-D'
    '''
        
    try:
        direcao = driver.find_element(By.CLASS_NAME, class_direcao).text
    except:
        direção = 'ONON-D'
    
    '''
    try:
        pais = driver.find_element(By.XPATH, xpath_pais).text
    except:
        pais = 'ONON-P'
    '''
    
    try:
        pais = driver.find_element(By.CLASS_NAME, class_pais).text
    except:
        pais = 'ONON-P'
        
    
    #print(titulo)
    #print(titulo_original)
    #print(ano)
    #print(duracao)

    print(link)
    print('{} ({}). {}. {}.'.format(titulo, titulo_original, pais, ano))
    print('Direção: {}'.format(direcao))
    print(duracao)
    print('\n')
# Out:
# Início: 21319
# Fim   : 1999999
# Step  : 270230
#
# https://www.imdb.com/title/tt0021319/
# Romance das Selvas (Título original: Rough Romance). ONON-P. 1930.
# Direção:
# 55 min
#
#
# https://www.imdb.com/title/tt0291549/
#  (). ONON-P. 0000.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt0561779/
# Little Raver (S7.E27). ONON-P. Elenco e equipe.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt0832009/
# The Cat and the Kitten's Rock & Roll (S1.E13). ONON-P. Elenco e equipe.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt1102239/
# In Search of Puppy Love (In Search of Puppy Love). ONON-P. 2007.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt1372469/
# Golden Getaway: Holidays in the Sun (S16.E22). ONON-P. Elenco e equipe.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt1642699/
# Kenneth's Sincere Apology (S2.E14). ONON-P. Elenco e equipe.
# Direção:
# 0
#
#
# https://www.imdb.com/title/tt1912929/
# Ein schöner Geburtstag (S1.E5). ONON-P. Elenco e equipe.
# Direção:
# ...

# %%
import random

print(random.randrange(0, 99999))
# Out:
# 67739

# %%
r = range(0, 10000)

for n in r:
    #print(n)
    print(str(n).zfill(7))
# Out:
# 0000000
# 0000001
# 0000002
# 0000003
# 0000004
# 0000005
# 0000006
# 0000007
# 0000008
# 0000009
# 0000010
# 0000011
# 0000012
# 0000013
# 0000014
# 0000015
# 0000016
# 0000017
# 0000018
# 0000019
# 0000020
# 0000021
# 0000022
# 0000023
# 0000024
# 0000025
# 0000026
# 0000027
# 0000028
# 0000029
# 0000030
# 0000031
# 0000032
# 0000033
# 0000034
# 0000035
# 0000036
# 0000037
# 0000038
# 0000039
# 0000040
# 0000041
# 0000042
# 0000043
# 0000044
# 0000045
# 0000046
# 0000047
# 0000048
# 0000049
# 0000050
# 0000051
# 0000052
# 0000053
# 0000054
# 0000055
# 0000056
# 0000057
# 0000058
# 0000059
# 0000060
# 0000061
# 0000062
# 0000063
# 0000064
# 0000065
# 0000066
# 0000067
# 0000068
# 0000069
# 0000070
# 0000071
# 0000072
# 0000073
# 0000074
# 0000075
# 0000076
# 0000077
# 0000078
# 0000079
# 0000080
# 0000081
# 0000082
# 0000083
# 0000084
# 0000085
# 0000086
# 0000087
# 0000088
# 0000089
# 0000090
# 0000091
# 0000092
# 0000093
# 0000094
# 0000095
# 0000096
# 0000097
# 0000098
# 0000099
# ...

# %%
list = [
    'https://www.imdb.com/title/tt0088763/'
]

xpath_titulo = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1'
xpath_titulo_original = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/div'
xpath_ano = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/span'
xpath_duracao = '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]'
xpath_direcao = '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/ul/li[1]/div/ul/li/a'

for a in list:
    driver.get(a)
    titulo = driver.find_element(By.XPATH, xpath_titulo).text
    titulo_original = driver.find_element(By.XPATH, xpath_titulo_original).text
    ano = driver.find_element(By.XPATH, xpath_ano).text
    duracao = driver.find_element(By.XPATH, xpath_duracao).text
    direcao = driver.find_element(By.XPATH, xpath_direcao).text
    #print(titulo)
    #print(titulo_original)
    #print(ano)
    #print(duracao)
    
    print('{} ({}). {}.'.format(titulo, titulo_original, ano))
    print('Direção: {}'.format(direcao))
    print(duracao)
    print('')








#"//span[text()='RANCHO RIO CLARO BAR E RESTAURANTE LTDA']")
# Out:
# De Volta para o Futuro (Título original: Back to the Future). .
# Direção: Robert Zemeckis
# 1 h 56 min
