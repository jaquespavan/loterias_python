# %% [markdown]
# ### Forma que fizemos na última aula (concatenando textos)

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print('O faturamento da loja foi ' + str(faturamento) + '.O custo da loja foi ' + str(custo) + '.Assim, o lucro da loja foi de ' + str(lucro))
# Out:
# O faturamento da loja foi 2000.O custo da loja foi 500.Assim, o lucro da loja foi de 1500

# %% [markdown]
# ### Método format

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print('O faturamento da loja foi {}. O custo da loja foi {}. Assim, o lucro foi {}.'.format(faturamento, custo, lucro))
# Out:
# O faturamento da loja foi 2000. O custo da loja foi 500. Assim, o lucro foi 1500.
